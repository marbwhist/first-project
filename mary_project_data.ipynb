# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# !pip install nltk

import nltk
from nltk.corpus import stopwords
print(stopwords.words('english'))
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from collections import Counter
from wordcloud import WordCloud, STOPWORDS
# from collections import Counter 
# movie_data=pd.DataFrame
# movie_data
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
movie_data=pd.read_csv('movie_data.csv')  
movie_df = pd.DataFrame(movie_data)
movie_df
movie_df = movie_df.drop(movie_df.columns[[ 0,3, 5,6,7,10, 11,12]], axis=1)

# %%
movie_df
# Out:
#    Main_Genre    Genre_2  imdb_rating                studio  \
# 0      Action  Adventure          7.4  Walt Disney Pictures
# 1      Action  Adventure          8.5  Walt Disney Pictures
# 2   Animation     Action          7.8                 Pixar
# 3      Action  Adventure          6.2    Universal Pictures
# 4      Action     Comedy          7.8      20th Century Fox
# ..        ...        ...          ...                   ...
# 93  Animation  Adventure          6.7    Paramount Pictures
# 94  Adventure     Action          6.7   Metro-Goldwyn-Mayer
# 95     Sci-Fi  Adventure          7.9    Paramount Pictures
# 96  Animation  Animation          8.4                 Pixar
# 97     Family  Adventure          6.6  Walt Disney Pictures
#
#                                        title  \
# 0                              Black Panther
# 1                     Avengers: Infinity War
# 2                              Incredibles 2
# 3             Jurassic World: Fallen Kingdom
# ...

# %%
master_list=[]

for index, row in movie_df.iterrows():
#     themes = row['synopsis'].split(' ')
#     if (type(row['synopsis']!= str)):
#   print(row['synopsis'], index)
             
    themes=str(row['synopsis']).split(' ')
    
#     print(themes)
    master_list.append(themes)
print(master_list)


word_counter=[]

for li in master_list:
    word_count=Counter(li).values()
#     print(word_count)
    word_count_key=Counter(li).keys()
    most_occur=Counter(li).most_common(5)
    print(most_occur)
#     print(word_count_key)

    word_dictionary=dict(zip(word_count_key, word_count))
    word_counter.append(word_dictionary)
#     print(word_dictionary)

word_df=pd.DataFrame(word_counter)
print(word_df)
#     for word in list:
#         word=word.lower()
# #     most_occur = str(row['synopsis']).most_common(4) 
          
# #         print(most_occur) 
#         print(word)
    

      
# movie_df

# # movie_df = movie_df.reindex(columns = movie_df.columns.tolist() + ['newcol1','newcol2'])
# movie_df
# data_set = movie_df['synopsis']
  
# split() returns list of all the words in the string 
# split_it = data_set.split() 
  
# # Pass the split_it list to instance of Counter class. 
# Counter = Counter(split_it) 
  
# # most_common() produces k frequently encountered 
# # input values and their respective counts. 
# most_occur = Counter.most_common(4) 
  
# print(most_occur) 
   
# movie_df['word1'] = []
# movie_df

# # copy of current data frame and then add columns 


# # example_sent = "This is a sample sentence, showing off the stop words filtration."
  
# stop_words = set(stopwords.words('english')) 
  
# word_tokens = word_tokenize(example_sent) 
  
# filtered_sentence = [w for w in word_tokens if not w in stop_words] 

# filtered_sentence = [] 

  
# for w in word_tokens: 
#     if w not in stop_words: 
#         filtered_sentence.append(w) 
  
# print(word_tokens) 
# print(filtered_sentence)
# Out:
# [["T'Challa,", 'heir', 'to', 'the', 'hidden', 'but', 'advanced', 'kingdom', 'of', 'Wakanda,', 'must', 'step', 'forward', 'to', 'lead', 'his', 'people', 'into', 'a', 'new', 'future', 'and', 'must', 'confront', 'a', 'challenger', 'from', 'his', "country's", 'past.'], ['The', 'Avengers', 'and', 'their', 'allies', 'must', 'be', 'willing', 'to', 'sacrifice', 'all', 'in', 'an', 'attempt', 'to', 'defeat', 'the', 'powerful', 'Thanos', 'before', 'his', 'blitz', 'of', 'devastation', 'and', 'ruin', 'puts', 'an', 'end', 'to', 'the', 'universe.'], ['The', 'Incredibles', 'hero', 'family', 'takes', 'on', 'a', 'new', 'mission,', 'which', 'involves', 'a', 'change', 'in', 'family', 'roles:', 'Bob', 'Parr', '(Mr', 'Incredible)', 'must', 'manage', 'the', 'house', 'while', 'his', 'wife', 'Helen', '(Elastigirl)', 'goes', 'out', 'to', 'save', 'the', 'world.'], ['When', 'the', "island's", 'dormant', 'volcano', 'begins', 'roaring', 'to', 'life,', 'Owen', 'and', 'Claire', 'mount', 'a', 'campaign', 'to', 'resc
# ...

# %%
# word1 = [] 
# word2=[]
# word3=[]
# word4=[]
# word5=[]
# movie_df
# Using 'Address' as the column name 
# and equating it to the list 
# movie_df['First Popular'] = word1

# movie_df.assign(Word1 = [])

# %%
for val in most_occur: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
#     # Converts each token into lowercase 
for i in range(len(tokens)): 
     tokens[i] = tokens[i].lower() 
      
    
cloud = WordCloud(width = 800, height = 800, 
               background_color ='white').generate((' '.join(sum(master_list, []))))
# print((' '.join(sum(master_list, []))))
 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
