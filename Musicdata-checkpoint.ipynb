# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
from scipy.stats import linregress


# url = "https://genius.p.rapidapi.com/artists/16775/songs"

# headers = {
#     'x-rapidapi-host': "genius.p.rapidapi.com",
#     'x-rapidapi-key': "a8f74bda32msh62f6fa7acf7b2adp1c1328jsn3e992db1ac31"
#     }

# response = requests.request("GET", url, headers=headers).json()
# df = pd.DataFrame(response)
# https://genius.p.rapidapi.com/artists/16775/songs/?rapidapi-key=a8f74bda32msh62f6fa7acf7b2adp1c1328jsn3e992db1ac31
# print(response)

top_songs = pd.read_csv("top songs of each year.csv")
# Out:
#     year  position                   artist  \
# 0   2000         1               Faith Hill
# 1   2000         2  Santana & The Product G
# 2   2000         3               Joe Thomas
# 3   2000         4                  Aaliyah
# 4   2000         5             Toni Braxton
# 5   2000         6     Rob Thomas & Santana
# 6   2000         7         Vertical Horizon
# 7   2000         8          Destiny's Child
# 8   2000         9                 Lonestar
# 9   2000        10          Matchbox Twenty
# 10  2000        11                  Madonna
# 11  2000        12                    Sisqo
# 12  2000        13         Three Doors Down
# 13  2000        14          Destiny's Child
# 14  2000        15                    Creed
# 15  2000        16                     Pink
# 16  2000        17                  Sonique
# 17  2000        18             Marc Anthony
# 18  2000        19                Macy Gray
# 19  2000        20                   N Sync
# ...
